# %% [markdown]
# <a href="https://colab.research.google.com/github/Hebabeg/Heba/blob/master/Churn_modeling_Hyperparameter_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
import pandas as pd

# %%
# !pip install tensorflow

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !pip install keras-tuner --upgrade

# %%
from kerastuner.tuners import RandomSearch

# %%
df=pd.read_csv('/content/churn.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
X = df.iloc[: , 3:13]
Y = df.iloc[: , 13]
df.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
def build_classifier(hp):
    classifier = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        classifier.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    classifier.add(layers.Dense(1, activation='sigmoid'))
    classifier.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy'])
    return classifier

# %%
tuner = RandomSearch(
    build_classifier,
    objective='accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='Churn Modeling')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project project/Churn Modeling/oracle.json
# INFO:tensorflow:Reloading Tuner from project/Churn Modeling/tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 22
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_5 (Int)
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
tuner.search(X_train, Y_train,
             epochs=5,
             validation_data=(X_test, Y_test))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/Churn Modeling
# Showing 10 best trials
# Objective(name='accuracy', direction='max')
# Trial summary
# Hyperparameters:
# num_layers: 20
# units_0: 352
# units_1: 288
# learning_rate: 0.01
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# units_9: 32
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# units_14: 32
# units_15: 32
# units_16: 32
# units_17: 32
# units_18: 32
# units_19: 32
# Score: 0.7960000038146973
# Trial summary
# Hyperparameters:
# num_layers: 8
# units_0: 448
# units_1: 320
# learning_rate: 0.01
# units_2: 480
# units_3: 480
# units_4: 288
# units_5: 128
# units_6: 448
# units_7: 160
# units_8: 64
# units_9: 480
# units_10: 96
# units_11: 64
# units_12: 224
# units_13: 64
# units_14: 224
# units_15: 160
# units_16: 288
# units_17: 352
# units_18: 384
# units_19: 416
# Score: 0.7960000038146973
# Trial summary
# Hyperparameters:
# num_layers: 15
# units_0: 480
# ...
